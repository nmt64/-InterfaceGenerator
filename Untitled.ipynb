# %% [markdown]
# Image processing with cards

# %%
#Import necessary library:
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
# %matplotlib inline
import cv2
from PIL import Image

# %% [markdown]
# Step 1: Load images

# %%
img = mpimg.imread('IMG_3417.jpg')
plt.imshow(img)

# %% [markdown]
# Step 2: Processing images

# %%
#Convert RGB TO GRAY
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
plt.imshow(gray, cmap='Greys_r')

# %%
#Canny edges detection

# %%
#Some other techiniques to process

# %% [markdown]
# Step 3: Show histogram of image to crop

# %%
#By converting to binary image, we can based on the amount of black and white pixel to crop
